# %%
# Python Script to Extract tweets of a
# particular Hashtag using Tweepy and Pandas

# import modules
import pandas as pd
import tweepy

# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")


# function to perform data extraction
def scrape(words, date_since, numtweet):
    # Creating DataFrame using pandas
    db = pd.DataFrame(columns=['username',
                               'description',
                               'location',
                               'following',
                               'followers',
                               'totaltweets',
                               'retweetcount',
                               'text',
                               'hashtags'])

    # We are using .Cursor() to search
    # through twitter for the required tweets.
    # The number of tweets can be
    # restricted using .items(number of tweets)
    tweets = tweepy.Cursor(api.search_tweets, words, lang="en", since_id=date_since,tweet_mode='extended').items(numtweet)

    # .Cursor() returns an iterable object. Each item in
    # the iterator has various attributes
    # that you can access to
    # get information about each tweet
    list_tweets = [tweet for tweet in tweets]

    # Counter to maintain Tweet Count
    i = 1

    # we will iterate over each tweet in the
    # list for extracting information about each tweet
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
        try:
                text = tweet.retweeted_status.full_text
        except AttributeError:
                text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
                hashtext.append(hashtags[j]['text'])

        # Here we are appending all the
        # extracted information in the DataFrame
        ith_tweet = [username, description,
                    location, following,
                    followers, totaltweets,
                    retweetcount, text, hashtext]
        db.loc[len(db)] = ith_tweet

        # Function call to print tweet data on screen
        printtweetdata(i, ith_tweet)
        i = i+1
        filename = 'scraped_tweets.csv'

        # we will save our database as a CSV file.
        db.to_csv(filename)

if __name__ == '__main__':
    # Enter your own credentials obtained
    # from your developer account
    consumer_key = "***"
    consumer_secret = "***"
    access_key = "***"
    access_secret = "***"

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    # Enter Hashtag and initial date
    print("Enter Twitter HashTag to search for")
    words = input()
    print("Enter Date since The Tweets are required in yyyy-mm-dd")
    date_since = input()

    # number of tweets you want to extract in one run
    numtweet = 100
    scrape(words, date_since, numtweet)
    print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# #Tripathi
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2010-01-01
#
# Tweet 1:
# Username:YourPod5
# Description:Just Another Podcast hoping to make it your favorite. Cricket ++.Available on all platforms as per your choice. Inspirations:SK, RJ Balaji, SKY Comm Team 🏏🎬🎙
# Location:
# Following Count:160
# Follower Count:126
# Total Tweets:742
# Retweet Count:1
# Tweet Text:With #SanjuSamson ruled out, who would you like to see replace him ?
#
# #INDvSL #CricketTwitter #BCCI #Tripathi #ruturajgaikwad #HardikPandya #CSK #SRH #IPL #RR
# Hashtags Used:['SanjuSamson', 'INDvSL', 'CricketTwitter', 'BCCI', 'Tripathi']
#
# Tweet 2:
# Username:YourPod5
# Description:Just Another Podcast hoping to make it your favorite. Cricket ++.Available on all platforms as per your choice. Inspirations:SK, RJ Balaji, SKY Comm Team 🏏🎬🎙
# Location:
# Following Count:160
# Follower Count:126
# Total Tweets:742
# Retweet Count:1
# Tweet Text:I think there is a good chance we can see Tripathi make his debut to replace Samson given he is better suited than Ruturaj to bat in the middle order.
#
# #INDvSL #CricketTwitter  #Tripathi #SanjuSamson #ruturajgaikwad @BCCI
# Hashtags Used:[]
#
# Tweet 3:
# Username:justcricketblog
# Description:Trying to enhance the quality of Cricket consumption. Youtube : https://t.co/uoEWV6YE57
# Location:
# Following Count:337
# Follower Count:441
# Total Tweets:3440
# Retweet Count:1
# Tweet Text:I think there is a good chance we can see Tripathi make his debut to replace Samson given he is better suited than Ruturaj to bat in the middle order.
#
# #INDvSL #CricketTwitter  #Tripathi #SanjuSamson #ruturajgaikwad @BCCI
# Hashtags Used:['INDvSL', 'CricketTwitter', 'Tripathi', 'SanjuSamson', 'ruturajgaikwad']
#
# Tweet 4:
# Username:justcricketblog
# Description:Trying to enhance the quality of Cricket consumption. Youtube : https://t.co/uoEWV6YE57
# Location:
# Following Count:337
# Follower Count:441
# Total Tweets:3440
# Retweet Count:1
# Tweet Text:With #SanjuSamson ruled out, who would you like to see replace him ?
#
# #INDvSL #CricketTwitter #BCCI #Tripathi #ruturajgaikwad #HardikPandya #CSK #SRH #IPL #RR
# Hashtags Used:['SanjuSamson', 'INDvSL', 'CricketTwitter', 'BCCI', 'Tripathi', 'ruturajgaikwad', 'HardikPandya', 'CSK', 'SRH', 'IPL', 'RR']
#
# Tweet 5:
# Username:ShivamDubey45
# Description:हिंदुस्तानी 🇮🇳
# हिंदू 🚩🦁
# श्री राम भक्त 🙏
# महाकाल का दीवाना 🔱
# Cricket Addict 🏏
# Location:Varanasi, India
# Following Count:204
# Follower Count:167
# Total Tweets:378
# Retweet Count:0
# Tweet Text:Wicket keeper batsman Jitesh Sharma has joined the team for remaining T20 games against sri lanka.
# #JiteshSharma #SanjuSamson #HardikPandya #Tripathi https://t.co/rf7KxYoler
# Hashtags Used:['JiteshSharma', 'SanjuSamson', 'HardikPandya', 'Tripathi']
#
# Tweet 6:
# Username:vipul_latiyan
# Description:HINDUSTANI🇮🇳
# Location:India
# Following Count:37
# Follower Count:70
# Total Tweets:126
# Retweet Count:0
# Tweet Text:The long wait will end for Tripathi.
# Then Rahul Tripathi will debut in tomorrow's match.🔥
# best wishes in advance to tripathi👍
#
# Wishing speedy recovery to #Samson! 🙌
#  @rahultripathi #RahulTripathi #tripathi #sanjusamon #sanju #INDvSL
# @CricCrazyJohns
# @mufaddal_vohra https://t.co/3mXA57dVPC
# Hashtags Used:['Samson', 'RahulTripathi', 'tripathi', 'sanjusamon', 'sanju', 'INDvSL']
#
# Tweet 7:
# Username:villainishhero
# Description:money money thala thalaivar 🙏🙏 Dhoni 😍
# Location:
# Following Count:31
# Follower Count:10
# Total Tweets:589
# Retweet Count:3
# Tweet Text:#Gill can't be above #Tripathi and #Ruturaj in the pecking order in T20s. GT quota la ulla thookki pottaan Pandya.
# Hashtags Used:['Gill', 'Tripathi', 'Ruturaj']
#
# Tweet 8:
# Username:shahimranhasan
# Description:Author| Biographer| ShortStoryWriter| Critic| Journalist ...Sub Editor @AwazTheVoiceUrd . Likes and retweets are not endorsements.
# Location: NewDelhi, India
# Following Count:209
# Follower Count:18
# Total Tweets:525
# Retweet Count:0
# Tweet Text:There is a misconception about Madarsas. This needs to change.(#ProfVKTripathi)
# #Tripathi
# #Islam #Muslim
# #indianmuslim
# #Madarsa
# @KanoongoPriyank
# @rakhitripathi https://t.co/yy9VMmMN2u
# Hashtags Used:['ProfVKTripathi', 'Tripathi', 'Islam', 'Muslim', 'indianmuslim', 'Madarsa']
#
# Tweet 9:
# Username:DarkConqueror22
# Description:Youtube content creator
# We Upload Gameplay Videos...
#
# #wwegames #PcGames #darkConqueror
#
# Instagram: dark_conqueror22
# Youtube: https://t.co/ZfQPwqRhvj
# Location:Trivandrum, India
# Following Count:41
# Follower Count:16
# Total Tweets:456
# Retweet Count:0
# Tweet Text:India vs Sri Lanka 1st T20 Highlights
# https://t.co/lvh2a4SzXw
#
# #IndiavsSrilanka #INDvSL #SanjuSamson #HardikPandya #Tripathi #mavi #India #BCCI #BCCISelectionCommittee #cricket22 #bigant #CricketTwitter #Cricket #RoyalRumble #mankad #BBL12
# Hashtags Used:['IndiavsSrilanka', 'INDvSL', 'SanjuSamson', 'HardikPandya', 'Tripathi', 'mavi', 'India', 'BCCI', 'BCCISelectionCommittee', 'cricket22', 'bigant', 'CricketTwitter', 'Cricket', 'RoyalRumble', 'mankad', 'BBL12']
#
# Tweet 10:
# Username:Sivaa2810
# Description:Just for fun.trying to learn and upgrade
# Location:
# Following Count:1038
# Follower Count:336
# Total Tweets:17529
# Retweet Count:3
# Tweet Text:#Gill can't be above #Tripathi and #Ruturaj in the pecking order in T20s. GT quota la ulla thookki pottaan Pandya.
# Hashtags Used:['Gill', 'Tripathi', 'Ruturaj']
#
# Tweet 11:
# Username:Bigboss_Kan_9
# Description:Only views like Audience
# Location:
# Following Count:8
# Follower Count:1
# Total Tweets:35
# Retweet Count:0
# Tweet Text:#Ruturaj #Tripathi should be given a chance. But no use of #IPL . Some one scored 7sixes in an over and orange cap holder is sitting in bench for long time .@BCCI 👌 https://t.co/OWlXoIAtLL
# Hashtags Used:['Ruturaj', 'Tripathi', 'IPL']
#
# Tweet 12:
# Username:believer348
# Description:எண்ணம் போல் வாழ்க்கை . Techie , Movie freak🍿, Cricket lover 🏏
# Location:Bengaluru, India
# Following Count:2058
# Follower Count:167
# Total Tweets:7782
# Retweet Count:3
# Tweet Text:#Gill can't be above #Tripathi and #Ruturaj in the pecking order in T20s. GT quota la ulla thookki pottaan Pandya.
# Hashtags Used:['Gill', 'Tripathi', 'Ruturaj']
#
# Tweet 13:
# Username:akshay14793
# Description:Just another 90s kid
# Location:
# Following Count:2429
# Follower Count:8217
# Total Tweets:160665
# Retweet Count:3
# Tweet Text:#Gill can't be above #Tripathi and #Ruturaj in the pecking order in T20s. GT quota la ulla thookki pottaan Pandya.
# Hashtags Used:['Gill', 'Tripathi', 'Ruturaj']
#
# Tweet 14:
# Username:Akshat__Jaiswal
# Description:Sports Lover.
# Indian from heart and soul🇮🇳
# Yaha tak agye ho to follow karke jao❤️
# Location:
# Following Count:122
# Follower Count:31
# Total Tweets:1457
# Retweet Count:1
# Tweet Text:Hard to say but #ruturajgaikwad   #IND team don't deserve you. Dnt like to see the match wish #SriLanka to win .@bhogleharsha  Why #hooda we have two all rounders and two spinners in playing 11 team could have given chance to #rutu r #Tripathi #Bcci  💩#politics #CSK
# Hashtags Used:['ruturajgaikwad', 'IND', 'SriLanka']
#
# Tweet 15:
# Username:curiouschlorid2
# Description:RTs = Endorsement ONLY. Most ppl on Twitter behave like they lose 100$ for each RT they do. Don't be Silly.
# RT every-Gud- thing U see. Life's Short,silly Goose
# Location:South-West Finland, Finland
# Following Count:381
# Follower Count:224
# Total Tweets:68179
# Retweet Count:0
# Tweet Text:#INDvsSL #INDvSL #SLvsIND #SLvIND
#
# Runs Scored
#
# Over 1 - 17 Runs
# O2 - 9 Runs
# O3 - 3 Runs
# O4 - 5 Runs
# O5 - 4 Runs
# O6 - 3 Runs
# O7 - 6 Runs
# O8 - 11 Runs
# O9 - 6 Runs
#
# #Shubmangill #Gill #Tripathi #IshanKishan #SuryakumarYadav #HardikPandya #hardik #SanjuSamson #Chahal
# Hashtags Used:['INDvsSL', 'INDvSL', 'SLvsIND', 'SLvIND', 'Shubmangill', 'Gill', 'Tripathi', 'IshanKishan', 'SuryakumarYadav', 'HardikPandya', 'hardik', 'SanjuSamson', 'Chahal']
#
# Tweet 16:
# Username:imabhi811
# Description:Engineer 🧑‍💻 | ICT 🇮🇳 | Jaipur📌
# Location:Jaipur, India
# Following Count:8
# Follower Count:9
# Total Tweets:474
# Retweet Count:0
# Tweet Text:Rahul tripathi is equally good against spin and pace &amp; not a hit and miss Player either. Plays with a good strike rate also but favouritism should be prior. Every one wants to see player from their franchise team.
# #INDvSL #Tripathi #Gill
# Hashtags Used:['INDvSL', 'Tripathi', 'Gill']
#
# Tweet 17:
# Username:girish_1001
# Description:#Indian, #Optimist, #Humanity must, #messi fan not #cr7 hater.
# Location:Chennai, India
# Following Count:364
# Follower Count:29
# Total Tweets:130
# Retweet Count:1
# Tweet Text:Hard to say but #ruturajgaikwad   #IND team don't deserve you. Dnt like to see the match wish #SriLanka to win .@bhogleharsha  Why #hooda we have two all rounders and two spinners in playing 11 team could have given chance to #rutu r #Tripathi #Bcci  💩#politics #CSK
# Hashtags Used:['ruturajgaikwad', 'IND', 'SriLanka', 'hooda', 'rutu', 'Tripathi', 'Bcci', 'politics', 'CSK']
#
# Tweet 18:
# Username:SasidaranSri
# Description:Thala fan
# Location:Udumalpet
# Following Count:654
# Follower Count:112
# Total Tweets:9418
# Retweet Count:0
# Tweet Text:@KKRiders @ShubmanGill @ShivamMavi23 Getting into gujarat titans will make it easy for anyone to get into playing 11, benching others? 🤔
# Interesting
# #Ruturaj #Tripathi
# Hashtags Used:['Ruturaj', 'Tripathi']
#
# Tweet 19:
# Username:cricket_keeda10
# Description:
# Location:
# Following Count:493
# Follower Count:311
# Total Tweets:208
# Retweet Count:0
# Tweet Text:No matter how technically good shubman gill is ,if u r selecting players like tripathi u have to play him . Approach changes when you bring players Who makes difference.
# #tripathi #bcci #INDvsSL
# Hashtags Used:['tripathi', 'bcci', 'INDvsSL']
#
# Tweet 20:
# Username:JeenatAmin
# Description:#Love
# #Food
# Location:India
# Following Count:397
# Follower Count:504
# Total Tweets:7742
# Retweet Count:0
# Tweet Text:Prof VK Tripathi: Madrassas are highly misunderstood
# #prof #tripathi
# https://t.co/zAV7xzmMZP
# Hashtags Used:['prof', 'tripathi']
#
# Tweet 21:
# Username:beingammy13
# Description:Zindgi pyar krne k liye kam hai… Log na jaane kaha se nafrat k liye waqt nikaal lete hain…I stand with farmers... #punjabibyblood
# Location:Chandigarh, India
# Following Count:246
# Follower Count:164
# Total Tweets:7918
# Retweet Count:0
# Tweet Text:#DoubleXL movie bht alag concept and really entertaining…
#
# Ladkiyon ko Over weight kehne wale aur Shaadi k waqt is reason se reject krne wale logon k chèhre pe Thappad hai…
#
# Grand salute to @humasqureshi #sonakshisinha
# #tripathi n #saira only on #Netflix
# #wakaoofilms
# Hashtags Used:['DoubleXL', 'sonakshisinha', 'tripathi', 'saira', 'Netflix', 'wakaoofilms']
#
# Tweet 22:
# Username:Lakshit1601
# Description:Sports Journalist, Anchor/Presentor
# Location:New Delhi
# Following Count:21
# Follower Count:8
# Total Tweets:65
# Retweet Count:0
# Tweet Text:India's team Key Point vs #SL:
#
# - Will #Dhawan be back in ODI?
# - #Pant rested or Dropped from Both Squads?
# - #Surya VC in T20i
# - #Ruturaj, #Samson, #Tripathi getting deserved opportunity
# - Did Virat Needed this Rest in T20?
# With also Rest From NZ Tour?
# #INDvsSL #IndianCricketTeam
# Hashtags Used:['SL', 'Dhawan', 'Pant', 'Surya', 'Ruturaj', 'Samson', 'Tripathi', 'INDvsSL', 'IndianCricketTeam']
#
# Tweet 23:
# Username:mirror7news
# Description:Get Every Latest News, Events and Updates around the World Quickly.
# #News #World #Politics #Entertainment #Sports #Gossips #Global #Trending #LatestNews #Tech
# Location:
# Following Count:4
# Follower Count:97534
# Total Tweets:31183
# Retweet Count:0
# Tweet Text:Pankaj Tripathi transforms into Atal Bihari Vajpayee for Main Atal Hoon. See first-look poster
#  &gt;&gt; Watch Now https://t.co/6DZYstloI8
#
# #Pankaj #Tripathi #transforms #Atal #News #NewsUpdate #LatestNews #TodayNews #BreakingNews #Trending #TrendingNews #Headlines https://t.co/xd6KvnuTKH
# Hashtags Used:['Pankaj', 'Tripathi', 'transforms', 'Atal', 'News', 'NewsUpdate', 'LatestNews', 'TodayNews', 'BreakingNews', 'Trending', 'TrendingNews', 'Headlines']
# Scraping has completed!
